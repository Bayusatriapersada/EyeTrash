# %%
import pickle
from fastai import *
from fastai.vision import *
from fastai.callbacks.hooks import *
from google.colab import drive

# %%
drive.mount('/content/gdrive',force_remount=True)
path = Path('gdrive/My Drive/Colab Notebooks/DATASET')
DATA_PATH = "gdrive/My Drive/Colab Notebooks/DATASET"
DATA_PATH2 = "gdrive/My Drive/Colab Notebooks/DATASET/bayu test"
datapath  = Path('gdrive/My Drive/ESP32-CAM')
infile = open(DATA_PATH+'/Trained_data_organic_Anorganic.pkl','rb')
best_model2 = pickle.load(infile)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
learn = load_learner(DATA_PATH, 'Trained_data_organic_Anorganic.pkl',test=ImageList.from_folder(datapath))

# %%
preds,y = learn.get_preds(ds_type=DatasetType.Test)
preds[:5]
# Out:
# tensor([[1.1397e-04, 9.9989e-01],
#         [7.5508e-04, 9.9924e-01],
#         [1.1798e-03, 9.9882e-01],
#         [3.6657e-03, 9.9633e-01],
#         [2.7263e-04, 9.9973e-01]])

# %%
img2 = open_image(datapath/'ESP32-CAM.jpg')
img2
# Out:
# Image (3, 480, 640)

# %%
pred_class,pred_idx,outputs = learn.predict(img2)
print(pred_class)
# Out:
# R
